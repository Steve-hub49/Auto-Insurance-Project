# %%
import pandas as pd

# %%
from flask import Flask
app = Flask(__name__)

# %%
df = pd.read_csv(r'C:\Users\steve\homework\Project_2_insurance\auto_insurance\data\ins_test.csv')

# %%
df
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       10/17/2014           OH
# 1                   228   42         342868        6/27/2006           IN
# 2                   134   29         687698         9/6/2000           OH
# 3                   256   41         227811        5/25/1990           IL
# 4                   228   44         367455         6/6/2014           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851        7/16/1991           OH
# 996                 285   41         186934         1/5/2014           IL
# 997                 130   34         918516        2/17/2003           OH
# 998                 458   62         533940       11/18/2011           IL
# 999                 456   60         556080       11/11/1996           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# ...

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine("postgresql://postgres:slfpostgres2435!@localhost:5432/auto_ins_test")

# %%
df.to_sql('auto_ins_test', engine, if_exists='replace')
# Out:
# ---------------------------------------------------------------------------
# DuplicateTable                            Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1277                     self.dialect.do_execute(
# -> 1278                         cursor, statement, parameters, context
#    1279                     )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     592     def do_execute(self, cursor, statement, parameters, context=None):
# --> 593         cursor.execute(statement, parameters)
#     594
#
# DuplicateTable: relation "ix_auto_ins_test_index" already exists
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-7-c61bf7258179> in <module>
# ...
